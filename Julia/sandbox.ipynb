# %%
function test()
    println("test")
end

test()
# Out:
# test

# %%
if true
    println("1")
elseif false
    println("2")
end
# Out:
# 1

# %%
a::Int8 = 0
# Out:
# 0

# %%
b = []
# Out:
# Any[]

# %%
# Out:
# FieldError: type Array has no field `append`, available fields: `ref`, `size`
#
#
#
# Stacktrace:
#
#  [1] getproperty(x::Vector{Any}, f::Symbol)
#
#    @ Base ./Base_compiler.jl:54
#
#  [2] top-level scope
#
#    @ ~/Documents/Projects/exercism/Julia/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sZmlsZQ==.jl:1
